# %% [markdown]
# # RNN concepts
# # End - End Project

# %%
import numpy as np

# %%
docs = ['recurrent neural network',
		'neural network',
		'artificial neural',
		'connections between nodes',
		'can create a cycle',
		'allowing output',
		'some nodes to affect subsequent',
		'exhibit temporal',
		'dynamic behavior',
		'type of Neural Network',
    'affect subsequent']

# %%
import tensorflow as tf
from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(oov_token = '<nothing>')

# %%
tokenizer.fit_on_texts(docs)

# %%
tokenizer.document_count
# Out:
# 11

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[7, 2, 3],
#  [2, 3],
#  [8, 2],
#  [9, 10, 4],
#  [11, 12, 13, 14],
#  [15, 16],
#  [17, 4, 18, 5, 6],
#  [19, 20],
#  [21, 22],
#  [23, 24, 2, 3],
#  [5, 6]]

# %%
tokenizer.word_index
# Out:
# {'<nothing>': 1,
#  'neural': 2,
#  'network': 3,
#  'nodes': 4,
#  'affect': 5,
#  'subsequent': 6,
#  'recurrent': 7,
#  'artificial': 8,
#  'connections': 9,
#  'between': 10,
#  'can': 11,
#  'create': 12,
#  'a': 13,
#  'cycle': 14,
#  'allowing': 15,
#  'output': 16,
#  'some': 17,
#  'to': 18,
#  'exhibit': 19,
#  'temporal': 20,
#  'dynamic': 21,
#  'behavior': 22,
#  'type': 23,
#  'of': 24}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('recurrent', 1),
#              ('neural', 4),
#              ('network', 3),
#              ('artificial', 1),
#              ('connections', 1),
#              ('between', 1),
#              ('nodes', 2),
#              ('can', 1),
#              ('create', 1),
#              ('a', 1),
#              ('cycle', 1),
#              ('allowing', 1),
#              ('output', 1),
#              ('some', 1),
#              ('to', 1),
#              ('affect', 2),
#              ('subsequent', 2),
#              ('exhibit', 1),
#              ('temporal', 1),
#              ('dynamic', 1),
#              ('behavior', 1),
#              ('type', 1),
#              ('of', 1)])

# %% [markdown]
# #Padding concept
#
# ```
# # This is formatted as code
# ```

# %%
from keras.utils import pad_sequences
post_sequences = pad_sequences(sequences,maxlen=5,padding='post')
pre_sequences = pad_sequences(sequences,maxlen=5,padding='pre')

# %%
post_sequences
# Out:
# array([[ 7,  2,  3,  0,  0],
#        [ 2,  3,  0,  0,  0],
#        [ 8,  2,  0,  0,  0],
#        [ 9, 10,  4,  0,  0],
#        [11, 12, 13, 14,  0],
#        [15, 16,  0,  0,  0],
#        [17,  4, 18,  5,  6],
#        [19, 20,  0,  0,  0],
#        [21, 22,  0,  0,  0],
#        [23, 24,  2,  3,  0],
#        [ 5,  6,  0,  0,  0]], dtype=int32)

# %%
pre_sequences
# Out:
# array([[ 0,  0,  7,  2,  3],
#        [ 0,  0,  0,  2,  3],
#        [ 0,  0,  0,  8,  2],
#        [ 0,  0,  9, 10,  4],
#        [ 0, 11, 12, 13, 14],
#        [ 0,  0,  0, 15, 16],
#        [17,  4, 18,  5,  6],
#        [ 0,  0,  0, 19, 20],
#        [ 0,  0,  0, 21, 22],
#        [ 0, 23, 24,  2,  3],
#        [ 0,  0,  0,  5,  6]], dtype=int32)

# %% [markdown]
# # Sentiment Analysis using RNN

# %%
from keras.datasets import imdb

# %%
imdb.load_data()

# %%
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten

# %%
(x_train,y_train),(x_test,y_test) = imdb.load_data()

# %%
print(len(x_train[0]))
# Out:
# 218

# %%
from keras.utils import pad_sequences
maxlen = 500
x_train = pad_sequences(x_train,maxlen=maxlen,padding = 'post')
x_test = pad_sequences(x_test,maxlen=maxlen,padding = 'post')

# %%
print(len(x_train[0]))
print(len(x_train[100]))
# Out:
# 500
# 500

# %%
model = Sequential()
model.add(SimpleRNN(32,input_shape=(500,1),return_sequences=False))
model.add(Dense(1,activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 32)                1088
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 1121 (4.38 KB)
# Trainable params: 1121 (4.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(metrics=['accuracy'],optimizer = 'adam',loss = 'binary_crossentropy')

# %%
model.fit(x_train,y_train,epochs = 10,validation_data = (x_test,y_test))
# Out:
# Epoch 1/10
# 782/782 [==============================] - 83s 103ms/step - loss: 0.7005 - accuracy: 0.5057 - val_loss: 0.6938 - val_accuracy: 0.5072
# Epoch 2/10
# 782/782 [==============================] - 81s 104ms/step - loss: 0.6940 - accuracy: 0.5088 - val_loss: 0.6936 - val_accuracy: 0.5077
# Epoch 3/10
# 782/782 [==============================] - 82s 105ms/step - loss: 0.6944 - accuracy: 0.5035 - val_loss: 0.6939 - val_accuracy: 0.5017
# Epoch 4/10
# 782/782 [==============================] - 79s 102ms/step - loss: 0.6939 - accuracy: 0.5022 - val_loss: 0.6937 - val_accuracy: 0.5051
# Epoch 5/10
# 782/782 [==============================] - 82s 105ms/step - loss: 0.6937 - accuracy: 0.5055 - val_loss: 0.6986 - val_accuracy: 0.5046
# Epoch 6/10
# 782/782 [==============================] - 82s 104ms/step - loss: 0.6937 - accuracy: 0.5052 - val_loss: 0.6936 - val_accuracy: 0.5043
# Epoch 7/10
# 782/782 [==============================] - 83s 106ms/step - loss: 0.6934 - accuracy: 0.5041 - val_loss: 0.6994 - val_accuracy: 0.4994
# Epoch 8/10
# 782/782 [==============================] - 78s 100ms/step - loss: 0.6937 - accuracy: 0.5053 - val_loss: 0.6951 - val_accuracy: 0.5048
# Epoch 9/10
# 782/782 [==============================] - 80s 103ms/step - loss: 0.6936 - accuracy: 0.5046 - val_loss: 0.6936 - val_accuracy: 0.5048
# Epoch 10/10
# 782/782 [==============================] - 80s 103ms/step - loss: 0.6936 - accuracy: 0.5017 - val_loss: 0.6931 - val_accuracy: 0.5047

# %%
import tensorflow
from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(oov_token = '<nothing>')

# %%
tokenizer.fit_on_texts(docs)
tokenizer.word_index
# Out:
# {'<nothing>': 1,
#  'neural': 2,
#  'network': 3,
#  'nodes': 4,
#  'affect': 5,
#  'subsequent': 6,
#  'recurrent': 7,
#  'artificial': 8,
#  'connections': 9,
#  'between': 10,
#  'can': 11,
#  'create': 12,
#  'a': 13,
#  'cycle': 14,
#  'allowing': 15,
#  'output': 16,
#  'some': 17,
#  'to': 18,
#  'exhibit': 19,
#  'temporal': 20,
#  'dynamic': 21,
#  'behavior': 22,
#  'type': 23,
#  'of': 24}

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[7, 2, 3],
#  [2, 3],
#  [8, 2],
#  [9, 10, 4],
#  [11, 12, 13, 14],
#  [15, 16],
#  [17, 4, 18, 5, 6],
#  [19, 20],
#  [21, 22],
#  [23, 24, 2, 3],
#  [5, 6]]

# %%
from keras.utils import pad_sequences
sequences = pad_sequences(sequences, padding = 'post')
sequences
# Out:
# array([[ 7,  2,  3,  0,  0],
#        [ 2,  3,  0,  0,  0],
#        [ 8,  2,  0,  0,  0],
#        [ 9, 10,  4,  0,  0],
#        [11, 12, 13, 14,  0],
#        [15, 16,  0,  0,  0],
#        [17,  4, 18,  5,  6],
#        [19, 20,  0,  0,  0],
#        [21, 22,  0,  0,  0],
#        [23, 24,  2,  3,  0],
#        [ 5,  6,  0,  0,  0]], dtype=int32)

# %% [markdown]
# #Model Architechture

# %%
from keras import Sequential
from keras.layers import Dense, SimpleRNN, Embedding, Flatten

model = Sequential()
model.add(Embedding(23, output_dim=2, input_length=500))
model.add(SimpleRNN(32, input_shape = (500,1), return_sequences= False))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 2)            46
#
#  simple_rnn_1 (SimpleRNN)    (None, 32)                1120
#
# =================================================================
# Total params: 1166 (4.55 KB)
# Trainable params: 1166 (4.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Embeddding and Rnn on IMDB data set

# %%
from keras.datasets import imdb
from keras import Sequential
from keras.layers import Dense, SimpleRNN, Embedding, Flatten
from keras.utils import pad_sequences

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words = 10000)
# (X_train, y_train), (X_test, y_test) = imdb.load_data()

# %%
#Data Processing
# step 1 - Visualisation of the data
# step 2 - Zero Padding
X_train = pad_sequences(X_train, padding = 'post', maxlen = 50)
X_test = pad_sequences(X_test, padding = 'post', maxlen = 50)

# %%
print(len(X_train[0]))
print(len(X_train[10]))
# Out:
# 50
# 50

# %%
model = Sequential()
model.add(Embedding(input_dim = 10000,output_dim = 2,input_length = 50))
model.add(SimpleRNN(32,return_sequences = False))
model.add(Dense(1,activation = 'sigmoid'))
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 50, 2)             20000
#
#  simple_rnn_5 (SimpleRNN)    (None, 32)                1120
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 21153 (82.63 KB)
# Trainable params: 21153 (82.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(metrics = ['accuracy'],optimizer='adam',loss='binary_crossentropy')

# %%
model.fit(X_train,y_train,epochs =5,validation_data = (X_test,y_test))
# Out:
# Epoch 1/5
# 782/782 [==============================] - 18s 22ms/step - loss: 0.6932 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4998
# Epoch 2/5
# 782/782 [==============================] - 15s 19ms/step - loss: 0.6906 - accuracy: 0.5100 - val_loss: 0.6993 - val_accuracy: 0.5062
# Epoch 3/5
# 782/782 [==============================] - 14s 18ms/step - loss: 0.6809 - accuracy: 0.5213 - val_loss: 0.6962 - val_accuracy: 0.5069
# Epoch 4/5
# 782/782 [==============================] - 14s 18ms/step - loss: 0.6683 - accuracy: 0.5278 - val_loss: 0.7055 - val_accuracy: 0.5054
# Epoch 5/5
# 782/782 [==============================] - 14s 18ms/step - loss: 0.6547 - accuracy: 0.5429 - val_loss: 0.7162 - val_accuracy: 0.5002

# %%
test_data = X_test[0][0:50].reshape(1,-1)

# %%
if model.predict(test_data)<0:
  print('Negative Review')
else:
  print('Positive Review')
# Out:
# 1/1 [==============================] - 0s 26ms/step
# Positive Review

# %% [markdown]
# # Stacked RNN

# %%
# model architecture
model = Sequential()
model.add(Embedding(input_dim = 10000, output_dim = 2, input_length = 50))
model.add(SimpleRNN(32, input_shape = (50,1), return_sequences=True))
model.add(SimpleRNN(32, input_shape = (50,1), return_sequences=False))
model.add(Dense(1,activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 50, 2)             20000
#
#  simple_rnn_6 (SimpleRNN)    (None, 50, 32)            1120
#
#  simple_rnn_7 (SimpleRNN)    (None, 32)                2080
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 23233 (90.75 KB)
# Trainable params: 23233 (90.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
